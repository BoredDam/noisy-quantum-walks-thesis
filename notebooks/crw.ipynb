# %%
from src.random_walk.random_walk import random_walk
import matplotlib.pyplot as plt

# %%
Y, X = random_walk(50, 100, 0.5, None)
plt.bar(X, Y, alpha=1)
plt.show()

# %%
Y, X = random_walk(50, 450, 0.1, 'circular')
plt.bar(X, Y, alpha=1)
plt.show()

# %%
Y, X = random_walk(50, 600, 0.5, 'reflecting')
plt.bar(X, Y, alpha=1)
plt.show()

# %%
Y, X = random_walk(100, 120, 0.1, 'absorbing')
plt.bar(X, Y, alpha=1)
plt.show()

# %%
Y, X = random_walk(50, 200, 0.5, 'reflecting')
plt.bar(X, Y, alpha=1)
plt.show()
