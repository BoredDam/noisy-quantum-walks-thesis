# %%
import matplotlib.pyplot as plt
import numpy as np
from src.quantum_random_walk.quantum_random_walk import noisy_circle_quantum_random_walk_1D, noisy_meas_circle_quantum_random_walk_1D

# %%
max_pos = 100
steps = 101
symm_qrw = True
SEED = 42
P = np.linspace(0,1,40)
dists = []
TIMES = 200



for p in P:
    np.random.seed(SEED)
    for t in range(TIMES):
        data, X = noisy_circle_quantum_random_walk_1D(max_pos, steps, 0.5, symm_qrw, 'H', p, None)
        Y = data[-1]
        X_odd = X[::2]
        Y_odd = Y[0::2]
        dists.append(Y)
    arr_dists = np.array(dists)
    arr_sum = np.sum(arr_dists, 0)
    Y = arr_sum / TIMES
    X_odd = X[::2]
    Y_odd = Y[0::2]
    dists.append(Y)
    plt.grid(True, which='major')
    plt.bar(X, Y, alpha=0.6)
    plt.plot(X_odd, Y_odd, '--')
    plt.title(f"p={p}")
    plt.show()
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[55], line 14
#      10
#      11 for p in P:
#      12     np.random.seed(SEED)
#      13     for t in range(TIMES):
# ---> 14         data, X = noisy_circle_quantum_random_walk_1D(max_pos, steps, 0.5, symm_qrw, 'H', p, None)
#      15         Y = data[-1]
#      16         X_odd = X[::2]
#      17         Y_odd = Y[0::2]
#
# File ~/Università/noisy-quantum-walks-thesis/src/quantum_random_walk/quantum_random_walk.py:74, in noisy_circle_quantum_random_walk_1D(max_pos, steps, odds, symmetrical, noise_type, noise_odds, seed)
#      72     else:
#      73         vec = U @ vec
# ---> 74     data.append(prob_pos)
#      76 return data, np.array(range(-N//2, N//2))
#
# KeyboardInterrupt:

# %%
max_pos = 100
steps = 101
symm_qrw = True
SEED = 42
P = np.linspace(0,1,40)
dists = []
TIMES = 200



for p in P:
    np.random.seed(SEED)
    for t in range(TIMES):
        data, X = noisy_meas_circle_quantum_random_walk_1D(max_pos, steps, 0.5, symm_qrw, p, None)
        Y = data[-1]
        X_odd = X[::2]
        Y_odd = Y[0::2]
        dists.append(Y)
    arr_dists = np.array(dists)
    arr_sum = np.sum(arr_dists, 0)
    Y = arr_sum / TIMES
    X_odd = X[::2]
    Y_odd = Y[0::2]
    dists.append(Y)
    plt.grid(True, which='major')
    plt.bar(X, Y, alpha=0.6)
    plt.plot(X_odd, Y_odd, '--')
    plt.title(f"p={p}")
    plt.show()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[56], line 14
#      10
#      11 for p in P:
#      12     np.random.seed(SEED)
#      13     for t in range(TIMES):
# ---> 14         data, X = noisy_meas_circle_quantum_random_walk_1D(max_pos, steps, 0.5, symm_qrw, 'H', p, None)
#      15         Y = data[-1]
#      16         X_odd = X[::2]
#      17         Y_odd = Y[0::2]
#
# TypeError: noisy_meas_circle_quantum_random_walk_1D() takes from 2 to 6 positional arguments but 7 were given

# %%
np.sum(Y)
# Out:
# np.float64(1.0000000000000138)
