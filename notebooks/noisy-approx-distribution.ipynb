# %%
import matplotlib.pyplot as plt
import numpy as np
from src.quantum_random_walk.quantum_random_walk import noisy_circle_quantum_random_walk_1D, noisy_meas_circle_quantum_random_walk_1D
import csv

# %%
max_pos = 101
steps = 100
symm_qrw = True
SEED = 42


dists = []
TIMES = 200
exp_name = "noisy_walk_H"

_, X = noisy_circle_quantum_random_walk_1D(max_pos, steps, 0.5, symm_qrw, 'H', 0, None) # just to have the X dim

P = np.linspace(0,0.8,50).round(2)

print(P)
for p in P:
    with open(f"./data/{exp_name}/{exp_name}_p_{p}.csv", "w") as csvfile:
        csvwriter = csv.writer(csvfile)
        csvwriter.writerow(X)
        np.random.seed(SEED)
        for t in range(TIMES):
            data, X = noisy_circle_quantum_random_walk_1D(max_pos, steps, 0.5, symm_qrw, 'H', p, None)
            Y = data[-1]
            X_odd = X[::2]
            Y_odd = Y[0::2]
            dists.append(Y)
            csvwriter.writerow(Y)
        arr_dists = np.array(dists)
        arr_sum = np.sum(arr_dists, 0)
        Y = arr_sum / TIMES
        X_odd = X[::2]
        Y_odd = Y[0::2]

    with open(f"./data/{exp_name}/{exp_name}_p_{p}_mean.csv", "w") as csvfile:
        csvwriter = csv.writer(csvfile)
        csvwriter.writerow(X)
        csvwriter.writerow(Y)

    plt.grid(True, which='major')
    plt.bar(X, Y, alpha=0.6)
    plt.plot(X_odd, Y_odd, '--')
    plt.title(f"noise type: H, p = {p}")    
    plt.savefig(f"./data/{exp_name}/{exp_name}_p_{p}_mean.pdf")
    plt.show()
# Out:
# [0.   0.02 0.03 0.05 0.07 0.08 0.1  0.11 0.13 0.15 0.16 0.18 0.2  0.21
#  0.23 0.24 0.26 0.28 0.29 0.31 0.33 0.34 0.36 0.38 0.39 0.41 0.42 0.44
#  0.46 0.47 0.49 0.51 0.52 0.54 0.56 0.57 0.59 0.6  0.62 0.64 0.65 0.67
#  0.69 0.7  0.72 0.73 0.75 0.77 0.78 0.8 ]

# %%
max_pos = 101
steps = 100
symm_qrw = True
SEED = 42


dists = []
TIMES = 200
exp_name = "noisy_walk_Z"

_, X = noisy_circle_quantum_random_walk_1D(max_pos, steps, 0.5, symm_qrw, 'Z', 0, None) # just to have the X dim

P = np.linspace(0,0.8,50).round(2)

print(P)
for p in P:
    with open(f"./data/{exp_name}/{exp_name}_p_{p}.csv", "w") as csvfile:
        csvwriter = csv.writer(csvfile)
        csvwriter.writerow(X)
        np.random.seed(SEED)
        for t in range(TIMES):
            data, X = noisy_circle_quantum_random_walk_1D(max_pos, steps, 0.5, symm_qrw, 'Z', p, None)
            Y = data[-1]
            X_odd = X[::2]
            Y_odd = Y[0::2]
            dists.append(Y)
            csvwriter.writerow(Y)
        arr_dists = np.array(dists)
        arr_sum = np.sum(arr_dists, 0)
        Y = arr_sum / TIMES
        X_odd = X[::2]
        Y_odd = Y[0::2]

    with open(f"./data/{exp_name}/{exp_name}_p_{p}_mean.csv", "w") as csvfile:
        csvwriter = csv.writer(csvfile)
        csvwriter.writerow(X)
        csvwriter.writerow(Y)

    plt.grid(True, which='major')
    plt.bar(X, Y, alpha=0.6)
    plt.plot(X_odd, Y_odd, '--')
    plt.title(f"noise type: Z, p = {p}")    
    plt.savefig(f"./data/{exp_name}/{exp_name}_p_{p}_mean.pdf")
    plt.show()
# Out:
# [0.   0.02 0.03 0.05 0.07 0.08 0.1  0.11 0.13 0.15 0.16 0.18 0.2  0.21
#  0.23 0.24 0.26 0.28 0.29 0.31 0.33 0.34 0.36 0.38 0.39 0.41 0.42 0.44
#  0.46 0.47 0.49 0.51 0.52 0.54 0.56 0.57 0.59 0.6  0.62 0.64 0.65 0.67
#  0.69 0.7  0.72 0.73 0.75 0.77 0.78 0.8 ]

# %%
max_pos = 101
steps = 100
symm_qrw = True
SEED = 42


dists = []
TIMES = 200
exp_name = "noisy_walk_X"

_, X = noisy_circle_quantum_random_walk_1D(max_pos, steps, 0.5, symm_qrw, 'X', 0, None) # just to have the X dim

P = np.linspace(0,0.8,50).round(2)

print(P)
for p in P:
    with open(f"./data/{exp_name}/{exp_name}_p_{p}.csv", "w") as csvfile:
        csvwriter = csv.writer(csvfile)
        csvwriter.writerow(X)
        np.random.seed(SEED)
        for t in range(TIMES):
            data, X = noisy_circle_quantum_random_walk_1D(max_pos, steps, 0.5, symm_qrw, 'X', p, None)
            Y = data[-1]
            X_odd = X[::2]
            Y_odd = Y[0::2]
            dists.append(Y)
            csvwriter.writerow(Y)
        arr_dists = np.array(dists)
        arr_sum = np.sum(arr_dists, 0)
        Y = arr_sum / TIMES
        X_odd = X[::2]
        Y_odd = Y[0::2]

    with open(f"./data/{exp_name}/{exp_name}_p_{p}_mean.csv", "w") as csvfile:
        csvwriter = csv.writer(csvfile)
        csvwriter.writerow(X)
        csvwriter.writerow(Y)

    plt.grid(True, which='major')
    plt.bar(X, Y, alpha=0.6)
    plt.plot(X_odd, Y_odd, '--')
    plt.title(f"noise type: X, p = {p}")    
    plt.savefig(f"./data/{exp_name}/{exp_name}_p_{p}_mean.pdf")
    plt.show()
