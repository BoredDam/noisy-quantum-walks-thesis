# %%
import matplotlib.pyplot as plt
from src.quantum_random_walk.quantum_random_walk import circle_quantum_random_walk_1D

# %%
max_pos = 5
steps = 5

for b in [(True, 'purple')]:
    data, X = circle_quantum_random_walk_1D(max_pos, steps, 0.5, b[0])
    Y = data[-1]
    X_odd = X[::2]
    Y_odd = Y[0::2]
    plt.grid(True, which='major', alpha=0.4)
    plt.bar(X, Y, alpha=0.6, color=b[1], width=1)
    plt.plot(X_odd, Y_odd, '--', color=b[1])
    plt.title('Passeggiata aleatoria quantistica con correzione, 5 passi')
    plt.savefig('qrw_5_step_unbiased.pdf')
    plt.show()

# %%
max_pos = 100
steps = 100

for b in [(False, 'darkorange')]:
    data, X = circle_quantum_random_walk_1D(max_pos, steps, 0.5, b[0])
    Y = data[-1]
    X_odd = X[::2]
    Y_odd = Y[0::2]
    plt.grid(True, which='major', alpha=0.4)
    plt.bar(X, Y, alpha=0.6, color=b[1], width=1)
    plt.plot(X_odd, Y_odd, '--', color=b[1])
    plt.title('Passeggiata aleatoria quantistica senza correzione, 100 passi')
    plt.savefig('qrw_100_step_biased.pdf')
    plt.show()

# %%
from src.random_walk.random_walk import random_walk

# %%
max_pos = 100
steps = 100
symm_qrw = True
c_Y, c_X = random_walk(max_pos, steps, 0.5, 'circular')
data, X = circle_quantum_random_walk_1D(max_pos, steps, 0.5, symm_qrw)
Y = data[-1]
X_odd = X[::2]
Y_odd = Y[0::2]
cX_odd = c_X[::2]
cY_odd = c_Y[0::2]
plt.grid(True, which='major')
plt.bar(X, Y, alpha=0.6, color='purple', label='quantum random walk')
plt.plot(X_odd, Y_odd, '--', color='purple')
plt.bar(c_X, c_Y, alpha=0.6, color='darkorange', label='classical random walk')
plt.plot(cX_odd, cY_odd, '--', color='darkorange')
plt.legend()
plt.title('Passeggiata aleatoria quantistica e classica a confronto')
plt.savefig('./images/quantum-vs-classical-rw.pdf')
plt.show()

# %%
Y = [7.888609052210011e-31,0.0,2.971812579366683e-27,0.0,2.594576801689542e-24,0.0,9.279519819485048e-22,0.0,1.7100594342873402e-19,0.0,1.8350768948877226e-17,0.0,1.2351488283361606e-15,0.0,5.4724984289435507e-14,0.0,1.6487499234167452e-12,0.0,3.45288371994072e-11,0.0,5.101322527524717e-10,0.0,5.369850052283021e-09,0.0,4.0573458993335776e-08,0.0,2.21869345163313e-07,0.0,8.909024500254249e-07,0.0,2.7047662553651775e-06,0.0,6.54007316993697e-06,0.0,1.3503852497996587e-05,0.0,2.5288729187789386e-05,0.0,4.4272138587684296e-05,0.0,7.333842798803604e-05,0.0,0.00011605482248503392,0.0,0.0001769753674108687,0.0,0.00026171906852484025,0.0,0.0003769131287269418,0.0,0.0005301615552846857,0.0,0.000730259327617496,0.0,0.000987632036338496,0.0,0.0013140905148123693,0.0,0.0017225495671993132,0.0,0.002227197035275239,0.0,0.0028436882797597553,0.0,0.0035892067042633206,0.0,0.004481965208922988,0.0,0.005541405892645163,0.0,0.006788253005020428,0.0,0.008245532538827295,0.0,0.00993952441704227,0.0,0.011899644029504868,0.0,0.014162222053154505,0.0,0.016775894348604384,0.0,0.019808483045096113,0.0,0.023360429173719773,0.0,0.027580831985027067,0.0,0.03266975869425553,0.0,0.0388315247428702,0.0,0.046121784643165596,0.0,0.054171818104312666,0.0,0.06192704880018186,0.0,0.06771286407784177,0.0,0.06987552116590451,0.0,0.06771286407784177,0.0,0.06192704880018186,0.0,0.054171818104312666,0.0,0.046121784643165596,0.0,0.0388315247428702,0.0,0.03266975869425553,0.0,0.027580831985027067,0.0,0.023360429173719773,0.0,0.019808483045096113,0.0,0.016775894348604384,0.0,0.014162222053154505,0.0,0.011899644029504868,0.0,0.00993952441704227,0.0,0.008245532538827295,0.0,0.006788253005020428,0.0,0.005541405892645163,0.0,0.004481965208922988,0.0,0.0035892067042633206,0.0,0.0028436882797597553,0.0,0.002227197035275239,0.0,0.0017225495671993132,0.0,0.0013140905148123693,0.0,0.000987632036338496,0.0,0.000730259327617496,0.0,0.0005301615552846857,0.0,0.0003769131287269418,0.0,0.00026171906852484025,0.0,0.0001769753674108687,0.0,0.00011605482248503392,0.0,7.333842798803604e-05,0.0,4.4272138587684296e-05,0.0,2.5288729187789386e-05,0.0,1.3503852497996587e-05,0.0,6.54007316993697e-06,0.0,2.7047662553651775e-06,0.0,8.909024500254249e-07,0.0,2.21869345163313e-07,0.0,4.0573458993335776e-08,0.0,5.369850052283021e-09,0.0,5.101322527524717e-10,0.0,3.45288371994072e-11,0.0,1.6487499234167452e-12,0.0,5.4724984289435507e-14,0.0,1.2351488283361606e-15,0.0,1.8350768948877226e-17,0.0,1.7100594342873402e-19,0.0,9.279519819485048e-22,0.0,2.594576801689542e-24,0.0,2.971812579366683e-27,0.0,7.888609052210011e-31
]
# 0.38

max_pos = 100
steps = 100
symm_qrw = True
c_Y, c_X = random_walk(max_pos, steps, 0.5, 'circular')
_, X = circle_quantum_random_walk_1D(max_pos, steps, 0.5, symm_qrw)
X_odd = X[::2]
Y_odd = Y[0::2]
cX_odd = c_X[::2]
cY_odd = c_Y[0::2]
plt.grid(True, which='major')
plt.bar(X, Y, alpha=0.6, color='purple', label='quantum random walk')
plt.plot(X_odd, Y_odd, '--', color='purple')
plt.bar(c_X, c_Y, alpha=0.6, color='darkorange', label='classical random walk')
plt.plot(cX_odd, cY_odd, '--', color='darkorange')

plt.xlabel('posizione')
plt.ylabel('probabilità')
plt.legend()
#plt.title('Passeggiata aleatoria quantistica e classica a confronto')
plt.savefig('./images/quantumnoisymeas-vs-classical-rw.pdf')
plt.show()
